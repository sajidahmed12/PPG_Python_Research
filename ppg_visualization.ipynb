# %%
import os
import csv  
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %% [markdown]
# ### Reading the PPG signals from csv file and converting it to NumPy Array for Visualization

# %%
filename ='signal_list_iphone7p'
csv_file=os.getcwd()+'/data/'+filename+'.csv'
s = pd.read_csv(csv_file, delimiter = ",")

total_ppg = len(sig)
print("Total Number of PPG Signals: "+str(total_ppg))

signals = np.array(s)
# Out:
# Total Number of PPG Signals: 6

# %% [markdown]
# ## Plotting a single PPG signal by user selection

# %%
plot_signal = 1                     # Insert the serial value for signal visualization

signal = signals[plot_signal]       # Preperaing Selected signal for visualization

# %%
# %matplotlib notebook
plt.plot(signal)
plt.title("PPG Signal", fontdict=None, loc='center')
plt.xlabel('Total Number of Frames/sec')
plt.ylabel('PPG singnal intensity ')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Save Individual PPG Signals as .png image in figures folder

# %%
plt.savefig("figures/signal_no_"+str(plot_signal)+"_from-csv-file.png", bbox_inches='tight')

# %% [markdown]
# ## Plotting All the PPG signals by user selection (Not yet working).

# %%
# %matplotlib notebook
c = 0
while(c<=total_ppg):
    plt.plot(signals[2])
    plt.title("PPG Signal", fontdict=None, loc='center')
    plt.xlabel('Total Number of Frames/sec')
    plt.ylabel('PPG singnal intensity ')
    plt.show()
    c+=1
# Out:
# <img src="data:image/png;base64,..." width="640">
